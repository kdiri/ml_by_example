# %%
import numpy as np
def sigmoid(input):
    return 1.0 / (1/np.exp(-input))

# %%
z = np.linspace(-8, 8, 1000)
y = sigmoid(z)

# %%
print(y)
# Out:
# [2.98095799e+03 2.93359521e+03 2.88698495e+03 2.84111526e+03
#  2.79597437e+03 2.75155069e+03 2.70783284e+03 2.66480960e+03
#  2.62246992e+03 2.58080296e+03 2.53979803e+03 2.49944459e+03
#  2.45973231e+03 2.42065100e+03 2.38219063e+03 2.34434133e+03
#  2.30709340e+03 2.27043728e+03 2.23436357e+03 2.19886302e+03
#  2.16392651e+03 2.12954509e+03 2.09570994e+03 2.06241237e+03
#  2.02964385e+03 1.99739598e+03 1.96566047e+03 1.93442919e+03
#  1.90369412e+03 1.87344739e+03 1.84368123e+03 1.81438801e+03
#  1.78556021e+03 1.75719044e+03 1.72927142e+03 1.70179599e+03
#  1.67475711e+03 1.64814783e+03 1.62196133e+03 1.59619089e+03
#  1.57082990e+03 1.54587186e+03 1.52131037e+03 1.49713912e+03
#  1.47335191e+03 1.44994264e+03 1.42690532e+03 1.40423401e+03
#  1.38192292e+03 1.35996632e+03 1.33835858e+03 1.31709414e+03
#  1.29616757e+03 1.27557349e+03 1.25530661e+03 1.23536175e+03
#  1.21573377e+03 1.19641766e+03 1.17740845e+03 1.15870126e+03
# ...

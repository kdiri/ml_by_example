# %%
import numpy
from matplotlib import pyplot


yhat = numpy.linspace(0, 1, 1000)
cost = -numpy.log(yhat)
pyplot.plot(yhat, cost)
pyplot.xlabel("Prediction")
pyplot.ylabel("Cost")
pyplot.xlim(0, 1)
pyplot.ylim(0, 7)
pyplot.show()
# Out:
# /Users/kdiri/PycharmProjects/Training/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
